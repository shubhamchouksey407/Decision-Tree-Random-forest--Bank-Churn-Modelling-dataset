# %%
import joblib

# %%
model=joblib.load(r"E:\DataScience-data\bank-model.pkl")

# %%
encoder=joblib.load(r"E:\DataScience-data\bank-model-encoder.pkl")

# %%
new_customer=[[619,"Germany",1,60,45020,3,1]]

# %%
test=encoder.transform(new_customer)

# %%
model.predict_proba(test)
# Out:
# array([[0., 1.]])

# %%
model.predict(test)
# Out:
# array([1], dtype=int64)
